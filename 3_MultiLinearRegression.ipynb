# %% [markdown]
# problem statement>> models the relationship between dependent variable y and more than on  eindependent variable x

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import load_diabetes
diabetes = load_diabetes()

# %%
diabetes
# Out:
# {'data': array([[ 0.03807591,  0.05068012,  0.06169621, ..., -0.00259226,
#           0.01990749, -0.01764613],
#         [-0.00188202, -0.04464164, -0.05147406, ..., -0.03949338,
#          -0.06833155, -0.09220405],
#         [ 0.08529891,  0.05068012,  0.04445121, ..., -0.00259226,
#           0.00286131, -0.02593034],
#         ...,
#         [ 0.04170844,  0.05068012, -0.01590626, ..., -0.01107952,
#          -0.04688253,  0.01549073],
#         [-0.04547248, -0.04464164,  0.03906215, ...,  0.02655962,
#           0.04452873, -0.02593034],
#         [-0.04547248, -0.04464164, -0.0730303 , ..., -0.03949338,
#          -0.00422151,  0.00306441]]),
#  'target': array([151.,  75., 141., 206., 135.,  97., 138.,  63., 110., 310., 101.,
#          69., 179., 185., 118., 171., 166., 144.,  97., 168.,  68.,  49.,
#          68., 245., 184., 202., 137.,  85., 131., 283., 129.,  59., 341.,
#          87.,  65., 102., 265., 276., 252.,  90., 100.,  55.,  61.,  92.,
# ...

# %%
diabetes.data
# Out:
# array([[ 0.03807591,  0.05068012,  0.06169621, ..., -0.00259226,
#          0.01990749, -0.01764613],
#        [-0.00188202, -0.04464164, -0.05147406, ..., -0.03949338,
#         -0.06833155, -0.09220405],
#        [ 0.08529891,  0.05068012,  0.04445121, ..., -0.00259226,
#          0.00286131, -0.02593034],
#        ...,
#        [ 0.04170844,  0.05068012, -0.01590626, ..., -0.01107952,
#         -0.04688253,  0.01549073],
#        [-0.04547248, -0.04464164,  0.03906215, ...,  0.02655962,
#          0.04452873, -0.02593034],
#        [-0.04547248, -0.04464164, -0.0730303 , ..., -0.03949338,
#         -0.00422151,  0.00306441]])

# %%
diabetes.feature_names
# Out:
# ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']

# %%
data = pd.DataFrame(diabetes.data,columns = diabetes.feature_names)
data
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 0    0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1   -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2    0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3   -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4    0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# ..        ...       ...       ...       ...       ...       ...       ...
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017293 -0.037344 -0.013840 -0.024993
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081413  0.083740  0.027809  0.173816
#
#            s4        s5        s6
# 0   -0.002592  0.019907 -0.017646
# ...

# %%
diabetes.target
# Out:
# array([151.,  75., 141., 206., 135.,  97., 138.,  63., 110., 310., 101.,
#         69., 179., 185., 118., 171., 166., 144.,  97., 168.,  68.,  49.,
#         68., 245., 184., 202., 137.,  85., 131., 283., 129.,  59., 341.,
#         87.,  65., 102., 265., 276., 252.,  90., 100.,  55.,  61.,  92.,
#        259.,  53., 190., 142.,  75., 142., 155., 225.,  59., 104., 182.,
#        128.,  52.,  37., 170., 170.,  61., 144.,  52., 128.,  71., 163.,
#        150.,  97., 160., 178.,  48., 270., 202., 111.,  85.,  42., 170.,
#        200., 252., 113., 143.,  51.,  52., 210.,  65., 141.,  55., 134.,
#         42., 111.,  98., 164.,  48.,  96.,  90., 162., 150., 279.,  92.,
#         83., 128., 102., 302., 198.,  95.,  53., 134., 144., 232.,  81.,
#        104.,  59., 246., 297., 258., 229., 275., 281., 179., 200., 200.,
#        173., 180.,  84., 121., 161.,  99., 109., 115., 268., 274., 158.,
#        107.,  83., 103., 272.,  85., 280., 336., 281., 118., 317., 235.,
# ...

# %%
data["target"] = diabetes.target
data
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 0    0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1   -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2    0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3   -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4    0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# ..        ...       ...       ...       ...       ...       ...       ...
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017293 -0.037344 -0.013840 -0.024993
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081413  0.083740  0.027809  0.173816
#
#            s4        s5        s6  target
# ...

# %%
x = data[['age','sex','bmi','bp']]
y= data['target']

# %%
x
# Out:
#           age       sex       bmi        bp
# 0    0.038076  0.050680  0.061696  0.021872
# 1   -0.001882 -0.044642 -0.051474 -0.026328
# 2    0.085299  0.050680  0.044451 -0.005670
# 3   -0.089063 -0.044642 -0.011595 -0.036656
# 4    0.005383 -0.044642 -0.036385  0.021872
# ..        ...       ...       ...       ...
# 437  0.041708  0.050680  0.019662  0.059744
# 438 -0.005515  0.050680 -0.015906 -0.067642
# 439  0.041708  0.050680 -0.015906  0.017293
# 440 -0.045472 -0.044642  0.039062  0.001215
# 441 -0.045472 -0.044642 -0.073030 -0.081413
#
# [442 rows x 4 columns]

# %%
y
# Out:
# 0      151.0
# 1       75.0
# 2      141.0
# 3      206.0
# 4      135.0
#        ...
# 437    178.0
# 438    104.0
# 439    132.0
# 440    220.0
# 441     57.0
# Name: target, Length: 442, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,random_state=2)

# %%
x_train
# Out:
#           age       sex       bmi        bp
# 70  -0.001882 -0.044642 -0.069797 -0.012556
# 37  -0.009147 -0.044642  0.011039 -0.057313
# 170  0.023546  0.050680 -0.020218 -0.036656
# 400 -0.023677 -0.044642  0.045529  0.090729
# 286 -0.038207 -0.044642 -0.054707 -0.077970
# ..        ...       ...       ...       ...
# 299  0.038076  0.050680 -0.013751 -0.015999
# 22  -0.085430 -0.044642 -0.004050 -0.009113
# 72   0.063504  0.050680 -0.004050 -0.012556
# 15  -0.052738  0.050680 -0.018062  0.080401
# 168  0.001751  0.050680  0.059541 -0.002228
#
# [353 rows x 4 columns]

# %%
x_test
# Out:
#           age       sex       bmi        bp
# 212  0.067136 -0.044642  0.003494  0.035644
# 422 -0.078165  0.050680  0.077863  0.052858
# 67   0.041708  0.050680 -0.014828 -0.017135
# 89  -0.045472 -0.044642 -0.048241 -0.019442
# 390  0.009016  0.050680  0.069241  0.059744
# ..        ...       ...       ...       ...
# 129  0.009016 -0.044642  0.016428  0.004658
# 417 -0.052738 -0.044642  0.071397 -0.074527
# 332  0.030811 -0.044642  0.104809  0.076958
# 150  0.023546 -0.044642  0.070319  0.025315
# 192  0.056239  0.050680 -0.030996  0.008101
#
# [89 rows x 4 columns]

# %%
y_train
# Out:
# 70      48.0
# 37     276.0
# 170     47.0
# 400    175.0
# 286     60.0
#        ...
# 299     83.0
# 22      68.0
# 72     202.0
# 15     171.0
# 168    268.0
# Name: target, Length: 353, dtype: float64

# %%
y_test
# Out:
# 212     73.0
# 422    233.0
# 67      97.0
# 89     111.0
# 390    277.0
#        ...
# 129    268.0
# 417     55.0
# 332    270.0
# 150    288.0
# 192     91.0
# Name: target, Length: 89, dtype: float64

# %%
from sklearn.linear_model import LinearRegression

# %%
multiRegre = LinearRegression()
multiRegre
# Out:
# LinearRegression()

# %%
multiRegre.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # testing the model

# %%
multiRegre.coef_
# Out:
# array([ 58.9702056 , -85.35224579, 792.48110133, 414.80794551])

# %%
multiRegre.intercept_
# Out:
# np.float64(152.10811544269586)

# %%
y_pred = multiRegre.predict(x_test)
y_pred
# Out:
# array([177.4319527 , 226.8042282 , 131.38295982, 106.94245038,
#        227.96838343, 261.03034311, 107.61235964,  89.89821966,
#        121.97081055, 193.64667222, 147.37995176, 163.35251798,
#        190.07852855, 123.60267893, 270.84681399, 120.11156508,
#        184.69698366, 118.53755325, 118.3430605 , 144.81003352,
#        184.50498258, 178.33577886, 128.84657034, 176.05783358,
#        139.36116865, 172.60749979, 238.09985331, 126.09058497,
#         82.75671966, 224.76884766, 207.21538817, 103.5612436 ,
#         66.86686768, 114.54901316, 154.94628408, 141.71540191,
#        182.25106501, 172.11959514, 130.24303495, 178.78000764,
#        179.09351977, 132.52144886, 170.52208768, 150.4445345 ,
#        185.68715781, 117.1393317 , 191.74260073, 223.80305139,
#        117.00950952, 156.04912704, 238.9868096 , 184.80162486,
#        161.43447557, 115.35534888, 189.95471409, 122.25536269,
#        141.62547347,  99.16190652, 171.84010719, 171.06663529,
# ...

# %%
x_test.shape
# Out:
# (89, 4)

# %%
y_test.shape
# Out:
# (89,)

# %%
for col in x_test.columns:
  plt.scatter(x_test[col],y_test,color = 'black')
  plt.plot(x_test[col],y_test)

# %%
from sklearn.metrics import mean_squared_error,r2_score,mean_absolute_error

# %%
y_pred = multiRegre.predict(x_test)

# %%
y_pred
# Out:
# array([177.4319527 , 226.8042282 , 131.38295982, 106.94245038,
#        227.96838343, 261.03034311, 107.61235964,  89.89821966,
#        121.97081055, 193.64667222, 147.37995176, 163.35251798,
#        190.07852855, 123.60267893, 270.84681399, 120.11156508,
#        184.69698366, 118.53755325, 118.3430605 , 144.81003352,
#        184.50498258, 178.33577886, 128.84657034, 176.05783358,
#        139.36116865, 172.60749979, 238.09985331, 126.09058497,
#         82.75671966, 224.76884766, 207.21538817, 103.5612436 ,
#         66.86686768, 114.54901316, 154.94628408, 141.71540191,
#        182.25106501, 172.11959514, 130.24303495, 178.78000764,
#        179.09351977, 132.52144886, 170.52208768, 150.4445345 ,
#        185.68715781, 117.1393317 , 191.74260073, 223.80305139,
#        117.00950952, 156.04912704, 238.9868096 , 184.80162486,
#        161.43447557, 115.35534888, 189.95471409, 122.25536269,
#        141.62547347,  99.16190652, 171.84010719, 171.06663529,
# ...

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 3590.83863249048

# %%
mean_absolute_error(y_test,y_pred)
# Out:
# 48.93612458583132

# %%
r2_score(y_test,y_pred)
# Out:
# 0.35009362753959494

# %% [markdown]
# **here the model is goood on the r2 method , r2 is giving the minimum error **

# %%
multiRegre.score(x_test,y_test)
# Out:
# 0.35009362753959494
